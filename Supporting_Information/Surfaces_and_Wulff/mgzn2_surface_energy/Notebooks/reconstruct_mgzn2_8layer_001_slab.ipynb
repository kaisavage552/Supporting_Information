# %%
import subprocess
subprocess.run(['pip', 'install', 'ase', 'pymatgen', '--break-system-packages', '-q'])
# Out:
# CompletedProcess(args=['pip', 'install', 'ase', 'pymatgen', '--break-system-packages', '-q'], returncode=0)

# %%
from ase.build import surface
from ase.io import read
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
from pymatgen.io.ase import AseAtomsAdaptor
from pymatgen.io.lammps.data import LammpsData
import os

# %%
alloy = read('bulk_structure/MgZn2_relaxed.cif')
slab = surface(alloy, (0, 0, 1), 8, vacuum=8)

# %%
print("Atom index | Species | Position (x, y, z)")
for i, atom in enumerate(slab):
    print(f"  {i:3d} | {atom.symbol:2s} | "
          f"x={atom.position[0]:.4f} "
          f"y={atom.position[1]:.4f} "
          f"z={atom.position[2]:.4f}")
# Out:
# Atom index | Species | Position (x, y, z)
#     0 | Mg | x=-0.0560 y=3.0317 z=11.2478
#     1 | Mg | x=2.6115 y=1.4916 z=12.3384
#     2 | Mg | x=2.6115 y=1.4916 z=15.5861
#     3 | Mg | x=-0.0560 y=3.0317 z=8.0000
#     4 | Zn | x=2.6115 y=4.5718 z=11.7931
#     5 | Zn | x=2.6115 y=4.5718 z=16.1314
#     6 | Zn | x=3.9268 y=0.7322 z=9.6239
#     7 | Zn | x=2.6115 y=3.0103 z=9.6239
#     8 | Zn | x=1.2962 y=0.7322 z=9.6239
#     9 | Zn | x=-1.3713 y=3.7910 z=13.9623
#    10 | Zn | x=-0.0560 y=1.5129 z=13.9623
#    11 | Zn | x=1.2593 y=3.7910 z=13.9623
#    12 | Mg | x=-0.0560 y=3.0317 z=19.9245
#    13 | Mg | x=2.6115 y=1.4916 z=21.0151
#    14 | Mg | x=2.6115 y=1.4916 z=24.2629
#    15 | Mg | x=-0.0560 y=3.0317 z=16.6768
#    16 | Zn | x=2.6115 y=4.5718 z=20.4698
#    17 | Zn | x=2.6115 y=4.5718 z=24.8082
#    18 | Zn | x=3.9268 y=0.7322 z=18.3006
#    19 | Zn | x=2.6115 y=3.0103 z=18.3006
#    20 | Zn | x=1.2962 y=0.7322 z=18.3006
#    21 | Zn | x=-1.3713 y=3.7910 z=22.6390
#    22 | Zn | x=-0.0560 y=1.5129 z=22.6390
#    23 | Zn | x=1.2593 y=3.7910 z=22.6390
#    24 | Mg | x=-0.0560 y=3.0317 z=28.6013
#    25 | Mg | x=2.6115 y=1.4916 z=29.6919
#    26 | Mg | x=2.6115 y=1.4916 z=32.9396
#    27 | Mg | x=-0.0560 y=3.0317 z=25.3535
#    28 | Zn | x=2.6115 y=4.5718 z=29.1466
#    29 | Zn | x=2.6115 y=4.5718 z=33.4850
#    30 | Zn | x=3.9268 y=0.7322 z=26.9774
#    31 | Zn | x=2.6115 y=3.0103 z=26.9774
#    32 | Zn | x=1.2962 y=0.7322 z=26.9774
#    33 | Zn | x=-1.3713 y=3.7910 z=31.3158
#    34 | Zn | x=-0.0560 y=1.5129 z=31.3158
#    35 | Zn | x=1.2593 y=3.7910 z=31.3158
#    36 | Mg | x=-0.0560 y=3.0317 z=37.2780
#    37 | Mg | x=2.6115 y=1.4916 z=38.3686
#    38 | Mg | x=2.6115 y=1.4916 z=41.6164
#    39 | Mg | x=-0.0560 y=3.0317 z=34.0303
#    40 | Zn | x=2.6115 y=4.5718 z=37.8233
#    41 | Zn | x=2.6115 y=4.5718 z=42.1617
#    42 | Zn | x=3.9268 y=0.7322 z=35.6541
#    43 | Zn | x=2.6115 y=3.0103 z=35.6541
#    44 | Zn | x=1.2962 y=0.7322 z=35.6541
#    45 | Zn | x=-1.3713 y=3.7910 z=39.9925
#    46 | Zn | x=-0.0560 y=1.5129 z=39.9925
#    47 | Zn | x=1.2593 y=3.7910 z=39.9925
#    48 | Mg | x=-0.0560 y=3.0317 z=45.9548
#    49 | Mg | x=2.6115 y=1.4916 z=47.0454
#    50 | Mg | x=2.6115 y=1.4916 z=50.2932
#    51 | Mg | x=-0.0560 y=3.0317 z=42.7070
#    52 | Zn | x=2.6115 y=4.5718 z=46.5001
#    53 | Zn | x=2.6115 y=4.5718 z=50.8385
#    54 | Zn | x=3.9268 y=0.7322 z=44.3309
#    55 | Zn | x=2.6115 y=3.0103 z=44.3309
#    56 | Zn | x=1.2962 y=0.7322 z=44.3309
#    57 | Zn | x=-1.3713 y=3.7910 z=48.6693
#    58 | Zn | x=-0.0560 y=1.5129 z=48.6693
#    59 | Zn | x=1.2593 y=3.7910 z=48.6693
#    60 | Mg | x=-0.0560 y=3.0317 z=54.6315
#    61 | Mg | x=2.6115 y=1.4916 z=55.7222
#    62 | Mg | x=2.6115 y=1.4916 z=58.9699
#    63 | Mg | x=-0.0560 y=3.0317 z=51.3838
#    64 | Zn | x=2.6115 y=4.5718 z=55.1769
#    65 | Zn | x=2.6115 y=4.5718 z=59.5152
#    66 | Zn | x=3.9268 y=0.7322 z=53.0077
#    67 | Zn | x=2.6115 y=3.0103 z=53.0077
#    68 | Zn | x=1.2962 y=0.7322 z=53.0077
#    69 | Zn | x=-1.3713 y=3.7910 z=57.3460
#    70 | Zn | x=-0.0560 y=1.5129 z=57.3460
#    71 | Zn | x=1.2593 y=3.7910 z=57.3460
#    72 | Mg | x=-0.0560 y=3.0317 z=63.3083
#    73 | Mg | x=2.6115 y=1.4916 z=64.3989
#    74 | Mg | x=2.6115 y=1.4916 z=67.6467
#    75 | Mg | x=-0.0560 y=3.0317 z=60.0605
#    76 | Zn | x=2.6115 y=4.5718 z=63.8536
#    77 | Zn | x=2.6115 y=4.5718 z=68.1920
#    78 | Zn | x=3.9268 y=0.7322 z=61.6844
#    79 | Zn | x=2.6115 y=3.0103 z=61.6844
#    80 | Zn | x=1.2962 y=0.7322 z=61.6844
#    81 | Zn | x=-1.3713 y=3.7910 z=66.0228
#    82 | Zn | x=-0.0560 y=1.5129 z=66.0228
#    83 | Zn | x=1.2593 y=3.7910 z=66.0228
#    84 | Mg | x=-0.0560 y=3.0317 z=71.9851
#    85 | Mg | x=2.6115 y=1.4916 z=73.0757
#    86 | Mg | x=2.6115 y=1.4916 z=76.3234
#    87 | Mg | x=-0.0560 y=3.0317 z=68.7373
#    88 | Zn | x=2.6115 y=4.5718 z=72.5304
#    89 | Zn | x=2.6115 y=4.5718 z=76.8687
#    90 | Zn | x=3.9268 y=0.7322 z=70.3612
#    91 | Zn | x=2.6115 y=3.0103 z=70.3612
#    92 | Zn | x=1.2962 y=0.7322 z=70.3612
#    93 | Zn | x=-1.3713 y=3.7910 z=74.6996
#    94 | Zn | x=-0.0560 y=1.5129 z=74.6996
#    95 | Zn | x=1.2593 y=3.7910 z=74.6996

# %%
from ase.visualize import view

# %%
view(slab)
# Out:
# <Popen: returncode: None args: ['C:\\Users\\Kai Savage\\anaconda3\\python.ex...>

# %%
from ase.build import surface, make_supercell
from ase.io import read
from ase.visualize import view

alloy = read('bulk_structure/MgZn2_relaxed.cif')
slab = surface(alloy, (0, 0, 1), 8, vacuum=8)

matrix = [[1, 0, 0],
          [0, 2, 0],
          [0, 0, 1]]
slab_doubled = make_supercell(slab, matrix)

print("Atom index | Species | Position (x, y, z)")
for i, atom in enumerate(slab_doubled):
    print(f"  {i:3d} | {atom.symbol:2s} | "
          f"x={atom.position[0]:.4f} "
          f"y={atom.position[1]:.4f} "
          f"z={atom.position[2]:.4f}")

view(slab_doubled)
# Out:
# Atom index | Species | Position (x, y, z)
#     0 | Mg | x=-0.0560 y=3.0317 z=11.2478
#     1 | Mg | x=2.6115 y=1.4916 z=12.3384
#     2 | Mg | x=2.6115 y=1.4916 z=15.5861
#     3 | Mg | x=-0.0560 y=3.0317 z=8.0000
#     4 | Zn | x=2.6115 y=4.5718 z=11.7931
#     5 | Zn | x=2.6115 y=4.5718 z=16.1314
#     6 | Zn | x=3.9268 y=0.7322 z=9.6239
#     7 | Zn | x=2.6115 y=3.0103 z=9.6239
#     8 | Zn | x=1.2962 y=0.7322 z=9.6239
#     9 | Zn | x=-1.3713 y=3.7910 z=13.9623
#    10 | Zn | x=-0.0560 y=1.5129 z=13.9623
#    11 | Zn | x=1.2593 y=3.7910 z=13.9623
#    12 | Mg | x=-0.0560 y=3.0317 z=19.9245
#    13 | Mg | x=2.6115 y=1.4916 z=21.0151
#    14 | Mg | x=2.6115 y=1.4916 z=24.2629
#    15 | Mg | x=-0.0560 y=3.0317 z=16.6768
#    16 | Zn | x=2.6115 y=4.5718 z=20.4698
#    17 | Zn | x=2.6115 y=4.5718 z=24.8082
#    18 | Zn | x=3.9268 y=0.7322 z=18.3006
#    19 | Zn | x=2.6115 y=3.0103 z=18.3006
#    20 | Zn | x=1.2962 y=0.7322 z=18.3006
#    21 | Zn | x=-1.3713 y=3.7910 z=22.6390
#    22 | Zn | x=-0.0560 y=1.5129 z=22.6390
#    23 | Zn | x=1.2593 y=3.7910 z=22.6390
#    24 | Mg | x=-0.0560 y=3.0317 z=28.6013
#    25 | Mg | x=2.6115 y=1.4916 z=29.6919
#    26 | Mg | x=2.6115 y=1.4916 z=32.9396
#    27 | Mg | x=-0.0560 y=3.0317 z=25.3535
#    28 | Zn | x=2.6115 y=4.5718 z=29.1466
#    29 | Zn | x=2.6115 y=4.5718 z=33.4850
#    30 | Zn | x=3.9268 y=0.7322 z=26.9774
#    31 | Zn | x=2.6115 y=3.0103 z=26.9774
#    32 | Zn | x=1.2962 y=0.7322 z=26.9774
#    33 | Zn | x=-1.3713 y=3.7910 z=31.3158
#    34 | Zn | x=-0.0560 y=1.5129 z=31.3158
#    35 | Zn | x=1.2593 y=3.7910 z=31.3158
#    36 | Mg | x=-0.0560 y=3.0317 z=37.2780
#    37 | Mg | x=2.6115 y=1.4916 z=38.3686
#    38 | Mg | x=2.6115 y=1.4916 z=41.6164
#    39 | Mg | x=-0.0560 y=3.0317 z=34.0303
#    40 | Zn | x=2.6115 y=4.5718 z=37.8233
#    41 | Zn | x=2.6115 y=4.5718 z=42.1617
#    42 | Zn | x=3.9268 y=0.7322 z=35.6541
#    43 | Zn | x=2.6115 y=3.0103 z=35.6541
#    44 | Zn | x=1.2962 y=0.7322 z=35.6541
#    45 | Zn | x=-1.3713 y=3.7910 z=39.9925
#    46 | Zn | x=-0.0560 y=1.5129 z=39.9925
#    47 | Zn | x=1.2593 y=3.7910 z=39.9925
#    48 | Mg | x=-0.0560 y=3.0317 z=45.9548
#    49 | Mg | x=2.6115 y=1.4916 z=47.0454
#    50 | Mg | x=2.6115 y=1.4916 z=50.2932
#    51 | Mg | x=-0.0560 y=3.0317 z=42.7070
#    52 | Zn | x=2.6115 y=4.5718 z=46.5001
#    53 | Zn | x=2.6115 y=4.5718 z=50.8385
#    54 | Zn | x=3.9268 y=0.7322 z=44.3309
#    55 | Zn | x=2.6115 y=3.0103 z=44.3309
#    56 | Zn | x=1.2962 y=0.7322 z=44.3309
#    57 | Zn | x=-1.3713 y=3.7910 z=48.6693
#    58 | Zn | x=-0.0560 y=1.5129 z=48.6693
#    59 | Zn | x=1.2593 y=3.7910 z=48.6693
#    60 | Mg | x=-0.0560 y=3.0317 z=54.6315
#    61 | Mg | x=2.6115 y=1.4916 z=55.7222
#    62 | Mg | x=2.6115 y=1.4916 z=58.9699
#    63 | Mg | x=-0.0560 y=3.0317 z=51.3838
#    64 | Zn | x=2.6115 y=4.5718 z=55.1769
#    65 | Zn | x=2.6115 y=4.5718 z=59.5152
#    66 | Zn | x=3.9268 y=0.7322 z=53.0077
#    67 | Zn | x=2.6115 y=3.0103 z=53.0077
#    68 | Zn | x=1.2962 y=0.7322 z=53.0077
#    69 | Zn | x=-1.3713 y=3.7910 z=57.3460
#    70 | Zn | x=-0.0560 y=1.5129 z=57.3460
#    71 | Zn | x=1.2593 y=3.7910 z=57.3460
#    72 | Mg | x=-0.0560 y=3.0317 z=63.3083
#    73 | Mg | x=2.6115 y=1.4916 z=64.3989
#    74 | Mg | x=2.6115 y=1.4916 z=67.6467
#    75 | Mg | x=-0.0560 y=3.0317 z=60.0605
#    76 | Zn | x=2.6115 y=4.5718 z=63.8536
#    77 | Zn | x=2.6115 y=4.5718 z=68.1920
#    78 | Zn | x=3.9268 y=0.7322 z=61.6844
#    79 | Zn | x=2.6115 y=3.0103 z=61.6844
#    80 | Zn | x=1.2962 y=0.7322 z=61.6844
#    81 | Zn | x=-1.3713 y=3.7910 z=66.0228
#    82 | Zn | x=-0.0560 y=1.5129 z=66.0228
#    83 | Zn | x=1.2593 y=3.7910 z=66.0228
#    84 | Mg | x=-0.0560 y=3.0317 z=71.9851
#    85 | Mg | x=2.6115 y=1.4916 z=73.0757
#    86 | Mg | x=2.6115 y=1.4916 z=76.3234
#    87 | Mg | x=-0.0560 y=3.0317 z=68.7373
#    88 | Zn | x=2.6115 y=4.5718 z=72.5304
#    89 | Zn | x=2.6115 y=4.5718 z=76.8687
#    90 | Zn | x=3.9268 y=0.7322 z=70.3612
#    91 | Zn | x=2.6115 y=3.0103 z=70.3612
#    92 | Zn | x=1.2962 y=0.7322 z=70.3612
#    93 | Zn | x=-1.3713 y=3.7910 z=74.6996
#    94 | Zn | x=-0.0560 y=1.5129 z=74.6996
#    95 | Zn | x=1.2593 y=3.7910 z=74.6996
#    96 | Mg | x=-2.7235 y=7.6519 z=11.2478
#    97 | Mg | x=-0.0560 y=6.1118 z=12.3384
#    98 | Mg | x=-0.0560 y=6.1118 z=15.5861
#    99 | Mg | x=-2.7235 y=7.6519 z=8.0000
#   100 | Zn | x=-0.0560 y=9.1920 z=11.7931
#   101 | Zn | x=-0.0560 y=9.1920 z=16.1314
#   102 | Zn | x=1.2593 y=5.3525 z=9.6239
#   103 | Zn | x=-0.0560 y=7.6306 z=9.6239
#   104 | Zn | x=-1.3713 y=5.3525 z=9.6239
#   105 | Zn | x=-4.0388 y=8.4113 z=13.9623
#   106 | Zn | x=-2.7235 y=6.1332 z=13.9623
#   107 | Zn | x=-1.4082 y=8.4113 z=13.9623
#   108 | Mg | x=-2.7235 y=7.6519 z=19.9245
#   109 | Mg | x=-0.0560 y=6.1118 z=21.0151
#   110 | Mg | x=-0.0560 y=6.1118 z=24.2629
#   111 | Mg | x=-2.7235 y=7.6519 z=16.6768
#   112 | Zn | x=-0.0560 y=9.1920 z=20.4698
#   113 | Zn | x=-0.0560 y=9.1920 z=24.8082
#   114 | Zn | x=1.2593 y=5.3525 z=18.3006
#   115 | Zn | x=-0.0560 y=7.6306 z=18.3006
#   116 | Zn | x=-1.3713 y=5.3525 z=18.3006
#   117 | Zn | x=-4.0388 y=8.4113 z=22.6390
#   118 | Zn | x=-2.7235 y=6.1332 z=22.6390
#   119 | Zn | x=-1.4082 y=8.4113 z=22.6390
#   120 | Mg | x=-2.7235 y=7.6519 z=28.6013
#   121 | Mg | x=-0.0560 y=6.1118 z=29.6919
#   122 | Mg | x=-0.0560 y=6.1118 z=32.9396
#   123 | Mg | x=-2.7235 y=7.6519 z=25.3535
#   124 | Zn | x=-0.0560 y=9.1920 z=29.1466
#   125 | Zn | x=-0.0560 y=9.1920 z=33.4850
#   126 | Zn | x=1.2593 y=5.3525 z=26.9774
#   127 | Zn | x=-0.0560 y=7.6306 z=26.9774
#   128 | Zn | x=-1.3713 y=5.3525 z=26.9774
#   129 | Zn | x=-4.0388 y=8.4113 z=31.3158
#   130 | Zn | x=-2.7235 y=6.1332 z=31.3158
#   131 | Zn | x=-1.4082 y=8.4113 z=31.3158
#   132 | Mg | x=-2.7235 y=7.6519 z=37.2780
#   133 | Mg | x=-0.0560 y=6.1118 z=38.3686
#   134 | Mg | x=-0.0560 y=6.1118 z=41.6164
#   135 | Mg | x=-2.7235 y=7.6519 z=34.0303
#   136 | Zn | x=-0.0560 y=9.1920 z=37.8233
#   137 | Zn | x=-0.0560 y=9.1920 z=42.1617
#   138 | Zn | x=1.2593 y=5.3525 z=35.6541
#   139 | Zn | x=-0.0560 y=7.6306 z=35.6541
#   140 | Zn | x=-1.3713 y=5.3525 z=35.6541
#   141 | Zn | x=-4.0388 y=8.4113 z=39.9925
#   142 | Zn | x=-2.7235 y=6.1332 z=39.9925
#   143 | Zn | x=-1.4082 y=8.4113 z=39.9925
#   144 | Mg | x=-2.7235 y=7.6519 z=45.9548
#   145 | Mg | x=-0.0560 y=6.1118 z=47.0454
#   146 | Mg | x=-0.0560 y=6.1118 z=50.2932
#   147 | Mg | x=-2.7235 y=7.6519 z=42.7070
#   148 | Zn | x=-0.0560 y=9.1920 z=46.5001
#   149 | Zn | x=-0.0560 y=9.1920 z=50.8385
#   150 | Zn | x=1.2593 y=5.3525 z=44.3309
#   151 | Zn | x=-0.0560 y=7.6306 z=44.3309
#   152 | Zn | x=-1.3713 y=5.3525 z=44.3309
#   153 | Zn | x=-4.0388 y=8.4113 z=48.6693
#   154 | Zn | x=-2.7235 y=6.1332 z=48.6693
#   155 | Zn | x=-1.4082 y=8.4113 z=48.6693
#   156 | Mg | x=-2.7235 y=7.6519 z=54.6315
#   157 | Mg | x=-0.0560 y=6.1118 z=55.7222
#   158 | Mg | x=-0.0560 y=6.1118 z=58.9699
#   159 | Mg | x=-2.7235 y=7.6519 z=51.3838
#   160 | Zn | x=-0.0560 y=9.1920 z=55.1769
#   161 | Zn | x=-0.0560 y=9.1920 z=59.5152
#   162 | Zn | x=1.2593 y=5.3525 z=53.0077
#   163 | Zn | x=-0.0560 y=7.6306 z=53.0077
#   164 | Zn | x=-1.3713 y=5.3525 z=53.0077
#   165 | Zn | x=-4.0388 y=8.4113 z=57.3460
#   166 | Zn | x=-2.7235 y=6.1332 z=57.3460
#   167 | Zn | x=-1.4082 y=8.4113 z=57.3460
#   168 | Mg | x=-2.7235 y=7.6519 z=63.3083
#   169 | Mg | x=-0.0560 y=6.1118 z=64.3989
#   170 | Mg | x=-0.0560 y=6.1118 z=67.6467
#   171 | Mg | x=-2.7235 y=7.6519 z=60.0605
#   172 | Zn | x=-0.0560 y=9.1920 z=63.8536
#   173 | Zn | x=-0.0560 y=9.1920 z=68.1920
#   174 | Zn | x=1.2593 y=5.3525 z=61.6844
#   175 | Zn | x=-0.0560 y=7.6306 z=61.6844
#   176 | Zn | x=-1.3713 y=5.3525 z=61.6844
#   177 | Zn | x=-4.0388 y=8.4113 z=66.0228
#   178 | Zn | x=-2.7235 y=6.1332 z=66.0228
#   179 | Zn | x=-1.4082 y=8.4113 z=66.0228
#   180 | Mg | x=-2.7235 y=7.6519 z=71.9851
#   181 | Mg | x=-0.0560 y=6.1118 z=73.0757
#   182 | Mg | x=-0.0560 y=6.1118 z=76.3234
#   183 | Mg | x=-2.7235 y=7.6519 z=68.7373
#   184 | Zn | x=-0.0560 y=9.1920 z=72.5304
#   185 | Zn | x=-0.0560 y=9.1920 z=76.8687
#   186 | Zn | x=1.2593 y=5.3525 z=70.3612
#   187 | Zn | x=-0.0560 y=7.6306 z=70.3612
#   188 | Zn | x=-1.3713 y=5.3525 z=70.3612
#   189 | Zn | x=-4.0388 y=8.4113 z=74.6996
#   190 | Zn | x=-2.7235 y=6.1332 z=74.6996
#   191 | Zn | x=-1.4082 y=8.4113 z=74.6996
# <Popen: returncode: None args: ['C:\\Users\\Kai Savage\\anaconda3\\python.ex...>

# %%
from ase.io import read
from ase.visualize import view
from pymatgen.io.ase import AseAtomsAdaptor
from pymatgen.io.lammps.data import LammpsData
import os

alloy = read('bulk_structure/MgZn2_relaxed.cif')
slab = surface(alloy, (0, 0, 1), 8, vacuum=8)

matrix = [[1, 0, 0],
          [0, 2, 0],
          [0, 0, 1]]
slab_doubled = make_supercell(slab, matrix)

# Move atom 185 to bottom surface
slab_doubled[185].position = [-0.056, 9.192, 7.464]

# Visualise to confirm
view(slab_doubled)

# Convert to pymatgen and write .data file
adaptor = AseAtomsAdaptor()
pymatgen_slab = adaptor.get_structure(slab_doubled)

os.makedirs("slabs", exist_ok=True)
lammps_data = LammpsData.from_structure(pymatgen_slab, atom_style="atomic")
lammps_data.write_file("slabs/mgzn2_001_8layers_reconstructed_ase.data")

mg_count = sum(1 for site in pymatgen_slab if site.species_string == "Mg")
zn_count = sum(1 for site in pymatgen_slab if site.species_string == "Zn")
print(f"Mg: {mg_count} Zn: {zn_count}")
print(f"Stoichiometric: {'YES' if zn_count == 2 * mg_count else 'NO'}")
# Out:
# Mg: 64 Zn: 128
# Stoichiometric: YES

# %%
#unrelaxed surface energy calculation
E_slab = -254.5558     # eV
E_bulk_per_fu = -16.195843 / 4   # eV per formula unit = -4.048961 eV
n = 192 / 3                 # formula units in slab = 32
A = 49.298197              # Ang^2

S_eV_per_ang2 = (E_slab - n * E_bulk_per_fu) / (2 * A)

# Convert to J/m^2 (1 eV/Ang^2 = 16.0218 J/m^2)
S_J_per_m2 = S_eV_per_ang2 * 16.0218

print(f"E_bulk per formula unit = {E_bulk_per_fu:.6f} eV")
print(f"n * E_bulk = {n * E_bulk_per_fu:.5f} eV")
print(f"E_slab - n*E_bulk = {E_slab - n * E_bulk_per_fu:.5f} eV")
print(f"S = {S_eV_per_ang2:.6f} eV/Ang^2")
print(f"S = {S_J_per_m2:.4f} J/m^2")
# Out:
# E_bulk per formula unit = -4.048961 eV
# n * E_bulk = -259.13349 eV
# E_slab - n*E_bulk = 4.57769 eV
# S = 0.046429 eV/Ang^2
# S = 0.7439 J/m^2

# %%
#relaxed surface energy calculation
E_slab_relaxed = -254.640911746661   # eV
E_bulk_per_fu = -16.195843 / 4  # eV per formula unit
n = 192 / 3                      # 32 formula units
A = 49.298197                   # Ang^2

S_relaxed_eV = (E_slab_relaxed - n * E_bulk_per_fu) / (2 * A)
S_relaxed_Jm2 = S_relaxed_eV * 16.0218

print(f"E_slab_relaxed - n*E_bulk = {E_slab_relaxed - n * E_bulk_per_fu:.5f} eV")
print(f"S relaxed = {S_relaxed_eV:.6f} eV/Ang^2")
print(f"S relaxed = {S_relaxed_Jm2:.4f} J/m^2")

# Compare with unrelaxed
S_unrelaxed_Jm2 = 0.7439
print(f"\nUnrelaxed S = {S_unrelaxed_Jm2:.4f} J/m^2")
print(f"Relaxed S   = {S_relaxed_Jm2:.4f} J/m^2")
print(f"Relaxation energy = {S_unrelaxed_Jm2 - S_relaxed_Jm2:.4f} J/m^2")
# Out:
# E_slab_relaxed - n*E_bulk = 4.49258 eV
# S relaxed = 0.045565 eV/Ang^2
# S relaxed = 0.7300 J/m^2
#
# Unrelaxed S = 0.7439 J/m^2
# Relaxed S   = 0.7300 J/m^2
# Relaxation energy = 0.0139 J/m^2
