# %%
import subprocess
subprocess.run(['pip', 'install', 'ase', 'pymatgen', '--break-system-packages', '-q'])
# Out:
# CompletedProcess(args=['pip', 'install', 'ase', 'pymatgen', '--break-system-packages', '-q'], returncode=0)

# %%
from ase.build import surface
from ase.io import read
from ase.visualize.plot import plot_atoms
import matplotlib.pyplot as plt
from pymatgen.io.ase import AseAtomsAdaptor
from pymatgen.io.lammps.data import LammpsData
import os

# %%
alloy = read('bulk_structure/MgZn2_relaxed.cif')
slab = surface(alloy, (1, 0, 0), 8, vacuum=8)

# %%
print("Atom index | Species | Position (x, y, z)")
for i, atom in enumerate(slab):
    print(f"  {i:3d} | {atom.symbol:2s} | "
          f"x={atom.position[0]:.4f} "
          f"y={atom.position[1]:.4f} "
          f"z={atom.position[2]:.4f}")
# Out:
# Atom index | Species | Position (x, y, z)
#     0 | Mg | x=2.6535 y=3.7377 z=8.7594
#     1 | Mg | x=5.3210 y=4.8283 z=10.2995
#     2 | Mg | x=5.3210 y=8.0761 z=10.2995
#     3 | Mg | x=2.6535 y=0.4899 z=8.7594
#     4 | Zn | x=2.6535 y=4.2830 z=11.8395
#     5 | Zn | x=2.6535 y=8.6214 z=11.8395
#     6 | Zn | x=4.0057 y=2.1138 z=11.0588
#     7 | Zn | x=1.3013 y=2.1138 z=11.0588
#     8 | Zn | x=5.3210 y=2.1138 z=8.7807
#     9 | Zn | x=3.9688 y=6.4522 z=8.0000
#    10 | Zn | x=1.3382 y=6.4522 z=8.0000
#    11 | Zn | x=2.6535 y=6.4522 z=10.2781
#    12 | Mg | x=5.3210 y=3.7377 z=13.3796
#    13 | Mg | x=2.6535 y=4.8283 z=14.9197
#    14 | Mg | x=2.6535 y=8.0761 z=14.9197
#    15 | Mg | x=5.3210 y=0.4899 z=13.3796
#    16 | Zn | x=5.3210 y=4.2830 z=16.4598
#    17 | Zn | x=5.3210 y=8.6214 z=16.4598
#    18 | Zn | x=1.3382 y=2.1138 z=15.6791
#    19 | Zn | x=3.9688 y=2.1138 z=15.6791
#    20 | Zn | x=2.6535 y=2.1138 z=13.4010
#    21 | Zn | x=1.3013 y=6.4522 z=12.6203
#    22 | Zn | x=4.0057 y=6.4522 z=12.6203
#    23 | Zn | x=5.3210 y=6.4522 z=14.8984
#    24 | Mg | x=2.6535 y=3.7377 z=17.9999
#    25 | Mg | x=5.3210 y=4.8283 z=19.5400
#    26 | Mg | x=5.3210 y=8.0761 z=19.5400
#    27 | Mg | x=2.6535 y=0.4899 z=17.9999
#    28 | Zn | x=2.6535 y=4.2830 z=21.0800
#    29 | Zn | x=2.6535 y=8.6214 z=21.0800
#    30 | Zn | x=4.0057 y=2.1138 z=20.2993
#    31 | Zn | x=1.3013 y=2.1138 z=20.2993
#    32 | Zn | x=5.3210 y=2.1138 z=18.0212
#    33 | Zn | x=3.9688 y=6.4522 z=17.2405
#    34 | Zn | x=1.3382 y=6.4522 z=17.2405
#    35 | Zn | x=2.6535 y=6.4522 z=19.5186
#    36 | Mg | x=5.3210 y=3.7377 z=22.6201
#    37 | Mg | x=2.6535 y=4.8283 z=24.1602
#    38 | Mg | x=2.6535 y=8.0761 z=24.1602
#    39 | Mg | x=5.3210 y=0.4899 z=22.6201
#    40 | Zn | x=5.3210 y=4.2830 z=25.7003
#    41 | Zn | x=5.3210 y=8.6214 z=25.7003
#    42 | Zn | x=1.3382 y=2.1138 z=24.9196
#    43 | Zn | x=3.9688 y=2.1138 z=24.9196
#    44 | Zn | x=2.6535 y=2.1138 z=22.6415
#    45 | Zn | x=1.3013 y=6.4522 z=21.8608
#    46 | Zn | x=4.0057 y=6.4522 z=21.8608
#    47 | Zn | x=5.3210 y=6.4522 z=24.1389
#    48 | Mg | x=2.6535 y=3.7377 z=27.2404
#    49 | Mg | x=5.3210 y=4.8283 z=28.7805
#    50 | Mg | x=5.3210 y=8.0761 z=28.7805
#    51 | Mg | x=2.6535 y=0.4899 z=27.2404
#    52 | Zn | x=2.6535 y=4.2830 z=30.3206
#    53 | Zn | x=2.6535 y=8.6214 z=30.3206
#    54 | Zn | x=4.0057 y=2.1138 z=29.5398
#    55 | Zn | x=1.3013 y=2.1138 z=29.5398
#    56 | Zn | x=5.3210 y=2.1138 z=27.2617
#    57 | Zn | x=3.9688 y=6.4522 z=26.4810
#    58 | Zn | x=1.3382 y=6.4522 z=26.4810
#    59 | Zn | x=2.6535 y=6.4522 z=28.7591
#    60 | Mg | x=5.3210 y=3.7377 z=31.8606
#    61 | Mg | x=2.6535 y=4.8283 z=33.4007
#    62 | Mg | x=2.6535 y=8.0761 z=33.4007
#    63 | Mg | x=5.3210 y=0.4899 z=31.8606
#    64 | Zn | x=5.3210 y=4.2830 z=34.9408
#    65 | Zn | x=5.3210 y=8.6214 z=34.9408
#    66 | Zn | x=1.3382 y=2.1138 z=34.1601
#    67 | Zn | x=3.9688 y=2.1138 z=34.1601
#    68 | Zn | x=2.6535 y=2.1138 z=31.8820
#    69 | Zn | x=1.3013 y=6.4522 z=31.1013
#    70 | Zn | x=4.0057 y=6.4522 z=31.1013
#    71 | Zn | x=5.3210 y=6.4522 z=33.3794
#    72 | Mg | x=2.6535 y=3.7377 z=36.4809
#    73 | Mg | x=5.3210 y=4.8283 z=38.0210
#    74 | Mg | x=5.3210 y=8.0761 z=38.0210
#    75 | Mg | x=2.6535 y=0.4899 z=36.4809
#    76 | Zn | x=2.6535 y=4.2830 z=39.5611
#    77 | Zn | x=2.6535 y=8.6214 z=39.5611
#    78 | Zn | x=4.0057 y=2.1138 z=38.7804
#    79 | Zn | x=1.3013 y=2.1138 z=38.7804
#    80 | Zn | x=5.3210 y=2.1138 z=36.5022
#    81 | Zn | x=3.9688 y=6.4522 z=35.7215
#    82 | Zn | x=1.3382 y=6.4522 z=35.7215
#    83 | Zn | x=2.6535 y=6.4522 z=37.9996
#    84 | Mg | x=5.3210 y=3.7377 z=41.1011
#    85 | Mg | x=2.6535 y=4.8283 z=42.6412
#    86 | Mg | x=2.6535 y=8.0761 z=42.6412
#    87 | Mg | x=5.3210 y=0.4899 z=41.1011
#    88 | Zn | x=5.3210 y=4.2830 z=44.1813
#    89 | Zn | x=5.3210 y=8.6214 z=44.1813
#    90 | Zn | x=1.3382 y=2.1138 z=43.4006
#    91 | Zn | x=3.9688 y=2.1138 z=43.4006
#    92 | Zn | x=2.6535 y=2.1138 z=41.1225
#    93 | Zn | x=1.3013 y=6.4522 z=40.3418
#    94 | Zn | x=4.0057 y=6.4522 z=40.3418
#    95 | Zn | x=5.3210 y=6.4522 z=42.6199

# %%
from ase.visualize import view

# %%
view(slab)
# Out:
# <Popen: returncode: None args: ['C:\\Users\\Kai Savage\\anaconda3\\python.ex...>

# %%
from ase.build import surface, make_supercell
from ase.io import read
from ase.visualize import view
from pymatgen.io.ase import AseAtomsAdaptor
from pymatgen.io.lammps.data import LammpsData
import os

alloy = read('bulk_structure/MgZn2_relaxed.cif')
slab = surface(alloy, (1, 0, 0), 8, vacuum=8)

matrix = [[1, 0, 0],
          [0, 1, 0],
          [0, 0, 1]]
slab_doubled = make_supercell(slab, matrix)

# Move atom 40 to bottom surface
slab_doubled[89].position = [5.321, 4.283, 7.220]

# Visualise to confirm
view(slab_doubled)

# Convert to pymatgen and write .data file
adaptor = AseAtomsAdaptor()
pymatgen_slab = adaptor.get_structure(slab_doubled)

os.makedirs("slabs", exist_ok=True)
lammps_data = LammpsData.from_structure(pymatgen_slab, atom_style="atomic")
lammps_data.write_file("slabs/mgzn2_100_8layers_reconstructed_ase.data")

mg_count = sum(1 for site in pymatgen_slab if site.species_string == "Mg")
zn_count = sum(1 for site in pymatgen_slab if site.species_string == "Zn")
print(f"Mg: {mg_count} Zn: {zn_count}")
print(f"Stoichiometric: {'YES' if zn_count == 2 * mg_count else 'NO'}")
# Out:
# Mg: 32 Zn: 64
# Stoichiometric: YES

# %%
from pymatgen.core.surface import Slab
from pymatgen.io.lammps.data import LammpsData

lammps_data = LammpsData.from_file(
    "slabs/mgzn2_100_8layers_reconstructed_ase.data",
    atom_style="atomic"
)
structure = lammps_data.structure

# Convert to Slab object
slab = Slab(
    structure.lattice,
    structure.species,
    structure.frac_coords,
    miller_index=(1, 0, 0),
    oriented_unit_cell=structure,
    shift=0,
    scale_factor=[[1,0,0],[0,1,0],[0,0,1]]
)

print(f"Symmetric: {slab.is_symmetric()}")
# Out:
# Symmetric: True

# %%
#unrelaxed surface energy calculation
E_slab = -125.86064      # eV
E_bulk_per_fu = -16.195843 / 4   # eV per formula unit = -4.048961 eV
n = 96 / 3                 # formula units in slab = 32
A = 46.289              # Ang^2

S_eV_per_ang2 = (E_slab - n * E_bulk_per_fu) / (2 * A)

# Convert to J/m^2 (1 eV/Ang^2 = 16.0218 J/m^2)
S_J_per_m2 = S_eV_per_ang2 * 16.0218

print(f"E_bulk per formula unit = {E_bulk_per_fu:.6f} eV")
print(f"n * E_bulk = {n * E_bulk_per_fu:.5f} eV")
print(f"E_slab - n*E_bulk = {E_slab - n * E_bulk_per_fu:.5f} eV")
print(f"S = {S_eV_per_ang2:.6f} eV/Ang^2")
print(f"S = {S_J_per_m2:.4f} J/m^2")
# Out:
# E_bulk per formula unit = -4.048961 eV
# n * E_bulk = -129.56674 eV
# E_slab - n*E_bulk = 3.70610 eV
# S = 0.040032 eV/Ang^2
# S = 0.6414 J/m^2

# %%
#relaxed surface energy calculation
E_slab_relaxed =   -126.006422780951 # eV
E_bulk_per_fu = -16.195843 / 4  # eV per formula unit
n = 96 / 3                      # 32 formula units
A = 46.289                    # Ang^2

S_relaxed_eV = (E_slab_relaxed - n * E_bulk_per_fu) / (2 * A)
S_relaxed_Jm2 = S_relaxed_eV * 16.0218

print(f"E_slab_relaxed - n*E_bulk = {E_slab_relaxed - n * E_bulk_per_fu:.5f} eV")
print(f"S relaxed = {S_relaxed_eV:.6f} eV/Ang^2")
print(f"S relaxed = {S_relaxed_Jm2:.4f} J/m^2")

# Compare with unrelaxed
S_unrelaxed_Jm2 = 0.6414
print(f"\nUnrelaxed S = {S_unrelaxed_Jm2:.4f} J/m^2")
print(f"Relaxed S   = {S_relaxed_Jm2:.4f} J/m^2")
print(f"Relaxation energy = {S_unrelaxed_Jm2 - S_relaxed_Jm2:.4f} J/m^2")
# Out:
# E_slab_relaxed - n*E_bulk = 3.56032 eV
# S relaxed = 0.038458 eV/Ang^2
# S relaxed = 0.6162 J/m^2
#
# Unrelaxed S = 0.6414 J/m^2
# Relaxed S   = 0.6162 J/m^2
# Relaxation energy = 0.0252 J/m^2
